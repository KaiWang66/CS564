# %%
# %load_ext sql
# %sql sqlite:///
# Out:
# 'Connected: @'

# %%
# %%sql
# CREATE TABLE T(
#     A varchar(255),
#     B varchar(255),
#     C varchar(255)
# );
# Out:
#  * sqlite:///
# Done.
# []

# %%
# %%sql
# INSERT INTO T
# VALUES(1,2,3);
# Out:
#  * sqlite:///
# 1 rows affected.
# []

# %%
# %%sql
# INSERT INTO T
# VALUES(1,3,2);
# Out:
#  * sqlite:///
# 1 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM T;
# Out:
#  * sqlite:///
# Done.
# [('1', '2', '3'), ('1', '3', '2'), ('1', '3', '2')]

# %%
# %%sql
# SELECT DISTINCT A,B,C
# FROM T;
# Out:
#  * sqlite:///
# Done.
# [('1', '2', '3'), ('1', '3', '2')]

# %%
# %%sql
# SELECT DISTINCT A
# FROM T;
# Out:
#  * sqlite:///
# Done.
# [('1',)]
