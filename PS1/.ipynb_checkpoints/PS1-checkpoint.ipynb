# %%
# %load_ext sql
# %sql sqlite:///PS1.db
# Out:
# 'Connected: @PS1.db'

# %% [markdown]
# Problem Set 1 [100 points]
# =======
#
# ### Deliverables:
#
# Submit your queries (and only those) using the `submission_template.txt` file that is posted on the class website. Follow the instructions on the file! Upload the file at Canvas (under PS1).
#
#
# ### Instructions / Notes:
#
# * Run the top cell above to load the database `PS1.db` (make sure the database file, `PS1.db`, is in the same directory as this IPython notebook is running in)
# * Some of the problems involve _changing_ this database (e.g. deleting rows)- you can always re-download `PS1.db` or make a copy if you want to start fresh!
# * You **may** create new IPython notebook cells to use for e.g. testing, debugging, exploring, etc.- this is encouraged in fact!- **just make sure that your final answer for each question is _in its own cell_ and _clearly indicated_**
# * When you see `In [*]:` to the left of the cell you are executing, this means that the code / query is _running_.
#     * **If the cell is hanging- i.e. running for too long: To restart the SQL connection, you must restart the entire python kernel**
#     * To restart kernel using the menu bar: "Kernel >> Restart >> Clear all outputs & restart"), then re-execute the sql connection cell at top
#     * You will also need to restart the connection if you want to load a different version of the database file
# * Remember:
#     * `%sql [SQL]` is for _single line_ SQL queries
#     * `%%sql [SQL]` is for _multi line_ SQL queries
# * _Have fun!_

# %% [markdown]
# Problem 1: Linear Algebra [25 points]
# ------------------------
#
# Two random 3x3 ($N=3$) matrices have been provided in tables `A` and `B`, having the following schema:
# > * `i INT`:   Row index
# > * `j INT`:   Column index
# > * `val INT`: Cell value
#
# **Note: all of your answers below _must_ work for any _square_ matrix sizes, i.e. any value of $N$**.
#
# Note how the matrices are represented- why do we choose this format?  Run the following queries to see the matrices in a nice format:

# %%
# %sql PRAGMA table_info(A);

# %%
# %%sql
# SELECT *
# FROM A;

# %%
# %sql SELECT group_concat(val, " , ") AS "A" FROM A GROUP BY i;

# %%
# %sql SELECT group_concat(val, " , ") AS "B" FROM B GROUP BY i;

# %% [markdown]
# ### Part (a): Matrix transpose [5 points]
#
# _Transposing_ a matrix $A$ is the operation of switching its rows with its columns- written $A^T$.  For example, if we have:
#
# $A=\begin{bmatrix}a & b & c\\ d & e & f\\ g & h & i\end{bmatrix}$
#
# Then:
#
# $A^T=\begin{bmatrix}a & d & g\\ b & e & h\\ c & f & i\end{bmatrix}$
#
# Write a _single SQL query_ to get the matrix transpose $A^T$ (in the same format as $A$- output tuples should be of format `(i,j,val)` where `i` is row, `j` is column, and the output is ordered by row then column index)
#
# Write your query here:

# %%
# %%sql
# SELECT i,j,val
# FROM A
# order by j, i;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (b): Dot product I [5 points]
#
# The _dot product_ of two vectors
#
# $a = \begin{bmatrix}a_1 & a_2 & \dots & a_n\end{bmatrix}$
#
# and
#
# $b = \begin{bmatrix}b_1 & b_2 & \dots & b_n\end{bmatrix}$
#
# is
#
# $a\cdot b = \sum_{i=1}^n a_ib_i = a_1b_1 + a_2b_2 + \dots + a_nb_n$
#
# Write a _single SQL query_ to take the dot product of the **second column of $A$** and the **third column of $B$.**
#
# Write your query here:

# %%
# %%sql
# SELECT *
# FROM A, B
# WHERE A.j = 1
# AND B.j = 2
# AND A.i = B.i;

# %%
# %%sql
# SELECT SUM(A.val * B.val) AS "SUM(A.val * B.val)"
# FROM A, B
# WHERE A.j = 1
# AND B.j = 2
# AND A.i = B.i;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (c): Dot product II [5 points]
#
# Write a _single SQL query_ to take the dot product of the **second _row_ of $A$** and the **third column of $B$.**
#
# Write your query here:

# %%
# %%sql
# SELECT SUM(A.val * B.val) AS "SUM(A.val * B.val)"
# FROM A, B
# WHERE A.i = 1
# AND B.j = 2
# AND A.j = B.i;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (d): Matrix multiplication [10 points]
#
# The product of a matrix $A$ (having dimensions $n\times m$) and a matrix $B$ (having dimensions $m\times p$) is the matrix $C$ (of dimension $n\times p$) having cell at row $i$ and column $j$ equal to:
#
# $C_{ij} = \sum_{k=1}^m A_{ik}B_{kj}$
#
# In other words, to multiply two matrices, get each cell of the resulting matrix $C$, $C_{ij}$, by taking the _dot product_ of the $i$th row of $A$ and the $j$th column of $B$.
#
# Write a single SQL query to get the matrix product of $A$ and $B$ (in the same format as $A$ and $B$).
#
# Write your query here:

# %%
# %%sql
# SELECT *, A.val * B.val AS VAL
# FROM A,B
# WHERE A.j = B.i;

# %%
# %%sql
# SELECT A.i, B.j, SUM(A.val * B.val) AS val
# FROM A,B
# WHERE A.j = b.i
# GROUP BY A.i, B.j;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# Problem 2: The Sales Database [35 points]
# ----------------------------------------------
#
# We've prepared and loaded a dataset related to sales data from a company. The dataset has the following schema:
#
# > `Holidays (WeekDate, IsHoliday)`
#
# > `Stores (Store, Type, Size)`
#
# > `TemporalData(Store,WeekDate,Temperature,FuelPrice,CPI,UnemploymentRate)`
#
# > `Sales (Store, Dept, WeekDate, WeeklySales)`
#
# Before you start writing queries on the database, find the schema and the constraints (keys, foreign keys).

# %%
# %sql PRAGMA table_info(Holidays);

# %%
# %sql PRAGMA table_info(Stores);

# %%
# %sql PRAGMA table_info(TemporalData);

# %%
# %sql PRAGMA table_info(Sales);

# %% [markdown]
# ### Part (a): Sales during Holidays [5 points]
#
# Using a single SQL query, find the stores with the largest and smallest overall sales during holiday weeks. Further requirements:
# * Use the `WITH` clause before the main body of the query to compute a subquery if necessary.
# * Return a relation with schema `(Store, AllSales)`.
#
# Write your query here:

# %%
# %%sql
# WITH S AS (SELECT Store, SUM(WeeklySales) AS AllSales
#            FROM Sales, Holidays
#            WHERE Sales.WeekDate = Holidays.WeekDate AND Holidays.IsHoliday = "TRUE"
#            GROUP BY Store)
# SELECT Store, ROUND(AllSales,2) AS AllSales
# FROM S
# WHERE AllSales IN (SELECT MIN(AllSales) From S)
#     OR AllSales IN (SELECT MAX(AllSales) From S);

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (b): When Holidays do not help Sales [10 points]
#
# Using a single SQL query, compute the **number** of non-holiday weeks that had larger sales than the overall average sales during holiday weeks. Further requirements:
# * Use the `WITH` clause before the main body of the query to compute a subquery if necessary.
# * Return a relation with schema `(NumNonHolidays)`.
#
# Write your query here:

# %%
# %%sql
# SELECT AVG(weeklysales)
# FROM Sales, Holidays
# WHERE Sales.weekdate = Holidays.weekdate AND Holidays.isholiday = "TRUE";

# %%
# %%sql
# WITH S AS (SELECT SUM(weeklysales) AS WS
#            FROM Sales, Holidays
#            WHERE Sales.weekdate = Holidays.weekdate AND Holidays.isholiday = "TRUE"
#            GROUP BY Sales.weekdate),
#      G AS (SELECT AVG(S.WS) AS AVGS
#            FROM S)
# SELECT *
# FROM G;

# %%
# %%sql
# SELECT *
# FROM Sales
# ORDER BY weekdate
# LIMIT 300;

# %%
# %%sql
# SELECT SUM(weeklysales) AS WS
# FROM Sales, Holidays
# WHERE Sales.weekdate = Holidays.weekdate AND Holidays.isholiday = "FALSE"
# GROUP BY Sales.weekdate
# ORDER BY WS DESC
# LIMIT 20;

# %%
# %%sql
# WITH S AS (SELECT SUM(weeklysales) AS WS
#            FROM Sales, Holidays
#            WHERE Sales.weekdate = Holidays.weekdate AND Holidays.isholiday = "TRUE"
#            GROUP BY Sales.weekdate),
#      G AS (SELECT AVG(S.WS) AS AVGS
#            FROM S),
#      NonHolidaySale AS (SELECT SUM(weeklysales) AS WS
#                         FROM Sales, Holidays
#                         WHERE Sales.weekdate = Holidays.weekdate AND Holidays.isholiday = "FALSE"
#                         GROUP BY Sales.weekdate)
# SELECT COUNT(*) AS NumNonHolidays
# FROM NonHolidaySale, G
# WHERE NonHolidaySale.WS > G.AVGS;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (c): Total Sales [5 points]
#
# Using a single SQL query, compute the total sales per month overall for each type of store. Further requirements:
# * Return a relation with schema `(type, Month, TotalSales)`.
#
# *Hint:* SQLite3 does not support native operations on the DATE datatype. To create a workaround, you can use the `LIKE` predicate and the string concatenation operator (||). You can also use the substring operator that SQLite3 supports (`substr`).
#
# Write your query here:

# %%
# %%sql
# SELECT Stores.type, substr(Sales.weekdate, 6, 2) AS Month, ROUND(SUM(weeklysales), 2) AS TotalSales
# FROM Stores, Sales
# WHERE Stores.store = Sales.store
# GROUP BY Stores.type, Month;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (d): Computing Correlations [15 points]
#
# The goal of this exercise is to find out whether each one of the 4 numeric attributes in `TemporalData` is
# positively or negatively correlated with sales.
#
# For our purposes, the intuitive notion of correlation is defined using a
# standard statistical quantity known as the *Pearson correlation coefficient*.
# Given two numeric random variables $X$ and $Y$, it is defined as follows:
#
# $$\rho_{X,Y} = \frac{E[XY] - E[X]E[Y]}{\sqrt{E[X^2] - E[X]^2} \sqrt{E[Y^2] - E[Y]^2}}$$
#
# On a given sample of data with $n$ examples each for $X$ and $Y$ (label them
# $x_i$ and $y_i$ respectively for $i = 1 \dots n$), it is estimated as follows:
#
# \begin{align*}
# \rho_{X,Y} = \frac{\sum_{i=1}^n (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^n (x_i - \bar{x})^2} \sqrt{\sum_{i=1}^n (y_i - \bar{y})^2}}
# \end{align*}
# In the above, $\bar{x}$ and $\bar{y}$ are the sample means, i.e.,
# $\bar{x} = \frac{1}{n}\sum_{i=1}^n x_i$, and $\bar{x} = \frac{1}{n}\sum_{i=1}^n y_i$.
#
# Further requirements:
# * Return a relation with schema `(AttributeName VARCHAR(20), CorrelationSign Integer)`.
# * The values of AttributeName can be hardcoded string literals, but the values
# of `CorrelationSign` must be computed automatically using SQL queries over
# the given database instance.
# * You can use multiple SQL statements to compute the result. It might be of help to create and update your own tables.
#
# Write your query here:

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# Problem 3: The Traveling SQL Server Salesman Problem [40 points]
# --------------------------------------------------
#
# SQL Server salespeople are lucky as far as traveling salespeople go- they only have to sell one or two big enterprise contracts, at one or two offices in Wisconsin, in order to make their monthly quota!
#
# Answer the following questions using the table of streets connecting company office buildings.
#
# **Note that for convenience all streets are included _twice_, as $A \rightarrow B$ and $B \rightarrow A$.  This should make some parts of the problem easier, but remember to take it into account!**

# %%
# %sql SELECT * FROM streets LIMIT 4;

# %% [markdown]
# ### Part (a): One-hop, two-hop, three-hop... [10 points]
#
# Our salesperson has stopped at UW-Madison, to steal some cool new RDBMS technology from CS564-ers, and now wants to go sell it to a company _within 10 miles of UW-Madison and _passing through no more than 3 distinct streets_.  Write a single query, not using `WITH` (see later on), to find all such companies.
#
# Your query should return the schema `(company, distance)` where distance is cumulative from UW-Madison.
#
# Write your query here:

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (b): A stop at the Farm [10 points]
#
# Now, our salesperson is out in the field, and wants to see all routes- and their distances- which will take him/her from a company $A$ to a company $B$, with the following constraints:
# * The route must _pass through UW-Madison (in order to pick up new RDBMS tech to sell!)
# * $A$ and $B$ must _each individually_ be _within 3 hops of UW-Madison
# * $A$ and $B$ must be different companies
# * _The total distance must be $<= 15$_
# * Do not use `WITH`
# * If you return a path $A \rightarrow B$, _also include $B \rightarrow A$ in your answer_
#
# In order to make your answer a bit cleaner, you may split into two queries, one of which creates a `VIEW`.  A view is a virtual table based on the output set of a SQL query.  A view can be used just like a normal table- the only difference under the hood is that the DBMS re-evaluates the query used to generate it each time a view is queried by a user (thus the data is always up-to date!)
#
# Here's a simple example of a view:

# %%
# %%sql
# DROP VIEW IF EXISTS short_streets;
# CREATE VIEW short_streets AS
# SELECT A, B, d FROM streets WHERE d < 3;
# SELECT * FROM short_streets LIMIT 3;

# %% [markdown]
# Write your query or queries here:

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (c): Ensuring acyclicity [10 points]
#
# You may have noticed at this point that the network, or **_graph_**, of streets in our `streets` table seems like it might be a **tree**.
#
# Recall that a **_tree_** is an undirected graph where each node has exactly one parent (or, is the root, and has none), but may have multiple children.  A slightly more formal definition of a tree is as follows:
#
# > An undirected graph $T$ is a **_tree_** if it is **connected**- meaning that there is a path between every pair of nodes- and has no **cycles** (informally, closed loops)
#
# Suppose that we guarantee the following about the graph of companies & streets determined by the `streets` table:
# * It is _connected_
# * It has no cycles of length $> 3$
#
# Write a _single SQL query_ which, if our graph is not a tree (i.e. if this isn't a [shaggy dog problem](https://en.wikipedia.org/wiki/Shaggy_dog_story)), **turns it into a tree** by deleting exactly _one_ street (*= two entries in our table!*).  Write your query here:

# %%
# %sql SELECT * FROM streets ORDER BY A;

# %%
# %%sql
# SELECT S1.id
# FROM streets S1, streets S2, streets S3
# WHERE S1.B = S2.A AND S2.B = S3.A AND S1.A = S3.B
# LIMIT 1;
# Out:
#  * sqlite:///PS1.db
# Done.
# []

# %%
# %%sql
# WITH ID AS (SELECT S1.id
#            FROM streets S1, streets S2, streets S3
#            WHERE S1.B = S2.A AND S2.B = S3.A AND S1.A = S3.B
#            LIMIT 1)
# DELETE FROM streets WHERE streets.id IN ID;

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Part (d): The longest path [10 points]
#
# In this part, we want to find the distance of the _longest path between any two companies_.
#
# Note that you should probably have done Part (c) first so that the graph of streets is a _tree_- this will make it much easier to work with!
#
# If you've done the other parts above, you might be skeptical that SQL can find paths of arbitrary lengths (which is what we need to do for this problem); how can we do this?
#
# There are some non-standard SQL functions- i.e. not universally supported by all SQL DBMSs- which are often incredibly useful.  One of these is the `WITH RECURSIVE` clause, supported by SQLite.
#
# A `WITH` clause lets you define what is essentially a view within a clause, mainly to clean up your SQL code.  A trivial example, to illustrate `WITH`:

# %%
# %%sql
# WITH companies(name) AS (
#     SELECT DISTINCT A FROM streets)
# SELECT *
# FROM companies
# WHERE name LIKE '%Gizmo%';

# %% [markdown]
# There is also a recursive variant, `WITH RECURSIVE`.  `WITH RECURSIVE` allows you to define a view just as above, except the table can be defined recursively.  A `WITH RECURSIVE` clause must be of the following form:
#
# ```
# WITH RECURSIVE
#     R(...) AS (
#         SELECT ...
#         UNION [ALL]
#         SELECT ... FROM R, ...
#     )
# ...
# ```
#
# `R` is the _recursive table_.  The `AS` clause contains two `SELECT` statements, conjoined by a `UNION` or `UNION ALL`; the first `SELECT` statement provides the initial / base case values, and the second or _recursive_ `SELECT` statement must include the recursive table in its `FROM` clause.
#
# Basically, the recursive `SELECT` statement continues executing on the tuple _most recently inserted into `R`_, inserting output rows back into `R`, and proceeding recursively in this way, until it no longer outputs any rows, and then stops.  See the [SQLite documentation](https://www.sqlite.org/lang_with.html) for more detail.
#
# The following example computes $5! = 5*4*3*2*1$ using `WITH RECURSIVE`:

# %%
# %%sql
# WITH
# RECURSIVE factorials(n,x) AS (
#         SELECT 1, 1
#         UNION
#         SELECT n+1, (n+1)*x FROM factorials WHERE n < 5)
# SELECT x FROM factorials WHERE n = 5;

# %% [markdown]
# In this example:
#
# 1. First, `(1,1)` is inserted into the table `factorials` (the base case).
# 2. Next, this tuple is returned by the recursive select, as `(n, x)`, and we insert the result back into `factorials`: `(1+1, (1+1)*1) = (2,2)`
# 3. Next, we do the same with the last tuple inserted into `factorials`- `(2,2)`- and insert `(2+1, (2+1)*2) = (3,6)`
# 4. And again: get `(3,6)` from `factorials` and insert `(3+1, (3+1)*6) = (4,24)` back in
# 5. And again: `(4,24)` -> `(4+1, (4+1)*24) = (5,120)`
# 6. Now the last tuple inserted into `factorials` is `(5, 120)`, which fails the `WHERE n < 5` clause, and thus our recursive select returns an empty set, and our `WITH RECURSIVE` statement concludes
# 7. Finally, now that our `WITH RECURSIVE` clause has concluded, we move on to the `SELECT x FROM factorials WHERE n=5` clause, which gets us our answer!

# %% [markdown]
# #### Now, your turn!
#
# Write a single SQL query that uses `WITH RECURSIVE` to find the furthest (by distance) pair of companies that still have a path of streets connecting them.  Your query should return `(A, B, distance)`.
#
# Write your query here:

# %%
# %sql SELECT A,B,d FROM streets GROUP BY A HAVING COUNT(*) = 1;
# Out:
#  * sqlite:///PS1.db
# Done.
# [('GadgetWorks', 'Gizmo Corp', 8),
#  ('Gizmo Collective', 'Thing Industries', 3),
#  ('Gizmo Industries', 'Widget Industries', 1),
#  ('GizmoWorks', 'Gadget Collective', 3),
#  ('Thing Collective', 'DooHickeyCo', 9),
#  ('ThingCo', 'DooHickey Corp', 6),
#  ('ThingWorks', 'GizmoCo', 5),
#  ('Widget Corp', 'Gadget Industries', 5),
#  ('WidgetCo', 'DooHickey Industries', 1),
#  ('WidgetWorks', 'Widget Collective', 1)]

# %%
# %%sql
# WITH S AS (SELECT A,B,d FROM streets WHERE A = "UW-Madison")
# SELECT *
# FROM S, streets
# WHERE S.B = streets.A AND (NOT (S.A = streets.B));
# Out:
#  * sqlite:///PS1.db
# Done.
# [('UW-Madison', 'DooHickey Collective', 7, 1, 'F', 'DooHickey Collective', 'Gizmo Corp', 2),
#  ('UW-Madison', 'Gadget Corp', 6, 3, 'F', 'Gadget Corp', 'DooHickey Corp', 3),
#  ('UW-Madison', 'Gadget Corp', 6, 7, 'F', 'Gadget Corp', 'Gadget Industries', 9),
#  ('UW-Madison', 'Gadget Collective', 9, 11, 'F', 'Gadget Collective', 'GizmoWorks', 3)]

# %%
# %%sql
# WITH RECURSIVE distance(c1, c2, d, p) AS (
#         SELECT A,B,d, A||"/"||B FROM streets GROUP BY A HAVING COUNT(*) = 1
#         UNION
#         SELECT c1, streets.B, streets.d + distance.d AS dis, p||"/"||streets.B
#         FROM streets, distance
#         WHERE (streets.B != c1) AND c2 = streets.A)
# SELECT * FROM distance LIMIT 100;
# Out:
#  * sqlite:///PS1.db
# Done.
# [('GadgetWorks', 'Gizmo Corp', 8, 'GadgetWorks/Gizmo Corp'),
#  ('Gizmo Collective', 'Thing Industries', 3, 'Gizmo Collective/Thing Industries'),
#  ('Gizmo Industries', 'Widget Industries', 1, 'Gizmo Industries/Widget Industries'),
#  ('GizmoWorks', 'Gadget Collective', 3, 'GizmoWorks/Gadget Collective'),
#  ('Thing Collective', 'DooHickeyCo', 9, 'Thing Collective/DooHickeyCo'),
#  ('ThingCo', 'DooHickey Corp', 6, 'ThingCo/DooHickey Corp'),
#  ('ThingWorks', 'GizmoCo', 5, 'ThingWorks/GizmoCo'),
#  ('Widget Corp', 'Gadget Industries', 5, 'Widget Corp/Gadget Industries'),
#  ('WidgetCo', 'DooHickey Industries', 1, 'WidgetCo/DooHickey Industries'),
#  ('WidgetWorks', 'Widget Collective', 1, 'WidgetWorks/Widget Collective'),
#  ('GadgetWorks', 'DooHickey Collective', 10, 'GadgetWorks/Gizmo Corp/DooHickey Collective'),
#  ('GadgetWorks', 'Widget Industries', 9, 'GadgetWorks/Gizmo Corp/Widget Industries'),
#  ('Gizmo Collective', 'DooHickeyWorks', 4, 'Gizmo Collective/Thing Industries/DooHickeyWorks'),
#  ('Gizmo Collective', 'GadgetCo', 12, 'Gizmo Collective/Thing Industries/GadgetCo'),
#  ('Gizmo Industries', 'Gizmo Corp', 2, 'Gizmo Industries/Widget Industries/Gizmo Corp'),
#  ('GizmoWorks', 'UW-Madison', 12, 'GizmoWorks/Gadget Collective/UW-Madison'),
#  ('Thing Collective', 'Thing Corp', 15, 'Thing Collective/DooHickeyCo/Thing Corp'),
#  ('Thing Collective', 'Widget Collective', 11, 'Thing Collective/DooHickeyCo/Widget Collective'),
#  ('ThingCo', 'DooHickeyWorks', 9, 'ThingCo/DooHickey Corp/DooHickeyWorks'),
#  ('ThingCo', 'Gadget Corp', 9, 'ThingCo/DooHickey Corp/Gadget Corp'),
#  ('ThingWorks', 'Thing Corp', 9, 'ThingWorks/GizmoCo/Thing Corp'),
#  ('Widget Corp', 'Gadget Corp', 14, 'Widget Corp/Gadget Industries/Gadget Corp'),
#  ('WidgetCo', 'Thing Corp', 4, 'WidgetCo/DooHickey Industries/Thing Corp'),
#  ('WidgetWorks', 'DooHickeyCo', 3, 'WidgetWorks/Widget Collective/DooHickeyCo'),
#  ('WidgetWorks', 'GadgetCo', 8, 'WidgetWorks/Widget Collective/GadgetCo'),
#  ('GadgetWorks', 'Gizmo Corp', 12, 'GadgetWorks/Gizmo Corp/DooHickey Collective/Gizmo Corp'),
#  ('GadgetWorks', 'UW-Madison', 17, 'GadgetWorks/Gizmo Corp/DooHickey Collective/UW-Madison'),
#  ('GadgetWorks', 'Gizmo Corp', 10, 'GadgetWorks/Gizmo Corp/Widget Industries/Gizmo Corp'),
#  ('GadgetWorks', 'Gizmo Industries', 10, 'GadgetWorks/Gizmo Corp/Widget Industries/Gizmo Industries'),
#  ('Gizmo Collective', 'DooHickey Corp', 7, 'Gizmo Collective/Thing Industries/DooHickeyWorks/DooHickey Corp'),
#  ('Gizmo Collective', 'Thing Industries', 5, 'Gizmo Collective/Thing Industries/DooHickeyWorks/Thing Industries'),
#  ('Gizmo Collective', 'Thing Industries', 21, 'Gizmo Collective/Thing Industries/GadgetCo/Thing Industries'),
#  ('Gizmo Collective', 'Widget Collective', 19, 'Gizmo Collective/Thing Industries/GadgetCo/Widget Collective'),
#  ('Gizmo Industries', 'DooHickey Collective', 4, 'Gizmo Industries/Widget Industries/Gizmo Corp/DooHickey Collective'),
#  ('Gizmo Industries', 'GadgetWorks', 10, 'Gizmo Industries/Widget Industries/Gizmo Corp/GadgetWorks'),
#  ('Gizmo Industries', 'Widget Industries', 3, 'Gizmo Industries/Widget Industries/Gizmo Corp/Widget Industries'),
#  ('GizmoWorks', 'DooHickey Collective', 19, 'GizmoWorks/Gadget Collective/UW-Madison/DooHickey Collective'),
#  ('GizmoWorks', 'Gadget Collective', 21, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Collective'),
#  ('GizmoWorks', 'Gadget Corp', 18, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Corp'),
#  ('Thing Collective', 'DooHickey Industries', 18, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickey Industries'),
#  ('Thing Collective', 'DooHickeyCo', 21, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickeyCo'),
#  ('Thing Collective', 'GizmoCo', 19, 'Thing Collective/DooHickeyCo/Thing Corp/GizmoCo'),
#  ('Thing Collective', 'DooHickeyCo', 13, 'Thing Collective/DooHickeyCo/Widget Collective/DooHickeyCo'),
#  ('Thing Collective', 'GadgetCo', 18, 'Thing Collective/DooHickeyCo/Widget Collective/GadgetCo'),
#  ('Thing Collective', 'WidgetWorks', 12, 'Thing Collective/DooHickeyCo/Widget Collective/WidgetWorks'),
#  ('ThingCo', 'DooHickey Corp', 12, 'ThingCo/DooHickey Corp/DooHickeyWorks/DooHickey Corp'),
#  ('ThingCo', 'Thing Industries', 10, 'ThingCo/DooHickey Corp/DooHickeyWorks/Thing Industries'),
#  ('ThingCo', 'DooHickey Corp', 12, 'ThingCo/DooHickey Corp/Gadget Corp/DooHickey Corp'),
#  ('ThingCo', 'Gadget Industries', 18, 'ThingCo/DooHickey Corp/Gadget Corp/Gadget Industries'),
#  ('ThingCo', 'UW-Madison', 15, 'ThingCo/DooHickey Corp/Gadget Corp/UW-Madison'),
#  ('ThingWorks', 'DooHickey Industries', 12, 'ThingWorks/GizmoCo/Thing Corp/DooHickey Industries'),
#  ('ThingWorks', 'DooHickeyCo', 15, 'ThingWorks/GizmoCo/Thing Corp/DooHickeyCo'),
#  ('ThingWorks', 'GizmoCo', 13, 'ThingWorks/GizmoCo/Thing Corp/GizmoCo'),
#  ('Widget Corp', 'DooHickey Corp', 17, 'Widget Corp/Gadget Industries/Gadget Corp/DooHickey Corp'),
#  ('Widget Corp', 'Gadget Industries', 23, 'Widget Corp/Gadget Industries/Gadget Corp/Gadget Industries'),
#  ('Widget Corp', 'UW-Madison', 20, 'Widget Corp/Gadget Industries/Gadget Corp/UW-Madison'),
#  ('WidgetCo', 'DooHickey Industries', 7, 'WidgetCo/DooHickey Industries/Thing Corp/DooHickey Industries'),
#  ('WidgetCo', 'DooHickeyCo', 10, 'WidgetCo/DooHickey Industries/Thing Corp/DooHickeyCo'),
#  ('WidgetCo', 'GizmoCo', 8, 'WidgetCo/DooHickey Industries/Thing Corp/GizmoCo'),
#  ('WidgetWorks', 'Thing Collective', 12, 'WidgetWorks/Widget Collective/DooHickeyCo/Thing Collective'),
#  ('WidgetWorks', 'Thing Corp', 9, 'WidgetWorks/Widget Collective/DooHickeyCo/Thing Corp'),
#  ('WidgetWorks', 'Widget Collective', 5, 'WidgetWorks/Widget Collective/DooHickeyCo/Widget Collective'),
#  ('WidgetWorks', 'Thing Industries', 17, 'WidgetWorks/Widget Collective/GadgetCo/Thing Industries'),
#  ('WidgetWorks', 'Widget Collective', 15, 'WidgetWorks/Widget Collective/GadgetCo/Widget Collective'),
#  ('GadgetWorks', 'DooHickey Collective', 14, 'GadgetWorks/Gizmo Corp/DooHickey Collective/Gizmo Corp/DooHickey Collective'),
#  ('GadgetWorks', 'Widget Industries', 13, 'GadgetWorks/Gizmo Corp/DooHickey Collective/Gizmo Corp/Widget Industries'),
#  ('GadgetWorks', 'DooHickey Collective', 24, 'GadgetWorks/Gizmo Corp/DooHickey Collective/UW-Madison/DooHickey Collective'),
#  ('GadgetWorks', 'Gadget Collective', 26, 'GadgetWorks/Gizmo Corp/DooHickey Collective/UW-Madison/Gadget Collective'),
#  ('GadgetWorks', 'Gadget Corp', 23, 'GadgetWorks/Gizmo Corp/DooHickey Collective/UW-Madison/Gadget Corp'),
#  ('GadgetWorks', 'DooHickey Collective', 12, 'GadgetWorks/Gizmo Corp/Widget Industries/Gizmo Corp/DooHickey Collective'),
#  ('GadgetWorks', 'Widget Industries', 11, 'GadgetWorks/Gizmo Corp/Widget Industries/Gizmo Corp/Widget Industries'),
#  ('GadgetWorks', 'Widget Industries', 11, 'GadgetWorks/Gizmo Corp/Widget Industries/Gizmo Industries/Widget Industries'),
#  ('Gizmo Collective', 'DooHickeyWorks', 10, 'Gizmo Collective/Thing Industries/DooHickeyWorks/DooHickey Corp/DooHickeyWorks'),
#  ('Gizmo Collective', 'Gadget Corp', 10, 'Gizmo Collective/Thing Industries/DooHickeyWorks/DooHickey Corp/Gadget Corp'),
#  ('Gizmo Collective', 'ThingCo', 13, 'Gizmo Collective/Thing Industries/DooHickeyWorks/DooHickey Corp/ThingCo'),
#  ('Gizmo Collective', 'DooHickeyWorks', 6, 'Gizmo Collective/Thing Industries/DooHickeyWorks/Thing Industries/DooHickeyWorks'),
#  ('Gizmo Collective', 'GadgetCo', 14, 'Gizmo Collective/Thing Industries/DooHickeyWorks/Thing Industries/GadgetCo'),
#  ('Gizmo Collective', 'DooHickeyWorks', 22, 'Gizmo Collective/Thing Industries/GadgetCo/Thing Industries/DooHickeyWorks'),
#  ('Gizmo Collective', 'GadgetCo', 30, 'Gizmo Collective/Thing Industries/GadgetCo/Thing Industries/GadgetCo'),
#  ('Gizmo Collective', 'DooHickeyCo', 21, 'Gizmo Collective/Thing Industries/GadgetCo/Widget Collective/DooHickeyCo'),
#  ('Gizmo Collective', 'GadgetCo', 26, 'Gizmo Collective/Thing Industries/GadgetCo/Widget Collective/GadgetCo'),
#  ('Gizmo Collective', 'WidgetWorks', 20, 'Gizmo Collective/Thing Industries/GadgetCo/Widget Collective/WidgetWorks'),
#  ('Gizmo Industries', 'Gizmo Corp', 6, 'Gizmo Industries/Widget Industries/Gizmo Corp/DooHickey Collective/Gizmo Corp'),
#  ('Gizmo Industries', 'UW-Madison', 11, 'Gizmo Industries/Widget Industries/Gizmo Corp/DooHickey Collective/UW-Madison'),
#  ('Gizmo Industries', 'Gizmo Corp', 18, 'Gizmo Industries/Widget Industries/Gizmo Corp/GadgetWorks/Gizmo Corp'),
#  ('Gizmo Industries', 'Gizmo Corp', 4, 'Gizmo Industries/Widget Industries/Gizmo Corp/Widget Industries/Gizmo Corp'),
#  ('GizmoWorks', 'Gizmo Corp', 21, 'GizmoWorks/Gadget Collective/UW-Madison/DooHickey Collective/Gizmo Corp'),
#  ('GizmoWorks', 'UW-Madison', 26, 'GizmoWorks/Gadget Collective/UW-Madison/DooHickey Collective/UW-Madison'),
#  ('GizmoWorks', 'UW-Madison', 30, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Collective/UW-Madison'),
#  ('GizmoWorks', 'DooHickey Corp', 21, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Corp/DooHickey Corp'),
#  ('GizmoWorks', 'Gadget Industries', 27, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Corp/Gadget Industries'),
#  ('GizmoWorks', 'UW-Madison', 24, 'GizmoWorks/Gadget Collective/UW-Madison/Gadget Corp/UW-Madison'),
#  ('Thing Collective', 'Thing Corp', 21, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickey Industries/Thing Corp'),
#  ('Thing Collective', 'WidgetCo', 19, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickey Industries/WidgetCo'),
#  ('Thing Collective', 'Thing Corp', 27, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickeyCo/Thing Corp'),
#  ('Thing Collective', 'Widget Collective', 23, 'Thing Collective/DooHickeyCo/Thing Corp/DooHickeyCo/Widget Collective'),
#  ('Thing Collective', 'Thing Corp', 23, 'Thing Collective/DooHickeyCo/Thing Corp/GizmoCo/Thing Corp'),
#  ('Thing Collective', 'ThingWorks', 24, 'Thing Collective/DooHickeyCo/Thing Corp/GizmoCo/ThingWorks'),
#  ('Thing Collective', 'Thing Corp', 19, 'Thing Collective/DooHickeyCo/Widget Collective/DooHickeyCo/Thing Corp'),
#  ('Thing Collective', 'Widget Collective', 15, 'Thing Collective/DooHickeyCo/Widget Collective/DooHickeyCo/Widget Collective')]

# %%
# %%sql
# WITH RECURSIVE distance(c1, c2, d, prev) AS (
#         SELECT A,B,d,A FROM streets GROUP BY A HAVING COUNT(*) = 1
#         UNION
#         SELECT c1, streets.B, streets.d + distance.d AS dis, c2
#         FROM streets, distance
#         WHERE (streets.B != prev) AND c2 = streets.A)
# SELECT c1 AS A,c2 AS B,MAX(d) AS "distance" FROM distance;
# Out:
#  * sqlite:///PS1.db
# Done.
# [('GadgetWorks', 'ThingWorks', 63)]

# %%
"""
Expected output below- don't re-evaluate this cell!

NOTE: A valid answer must work for ALL inputs of the given type,
not just this example.  I.e. do not hardcode around this answer / etc!
"""

# %% [markdown]
# ### Note on alternate output
#
# **NOTE:** The **_distance_** of the longest path could be **49 _OR_ 63** depending on which street you deleted in Part (c)!
